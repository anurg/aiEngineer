# %% [markdown]
# ## 1. A model, stripped to its essence",
#
# "Forget chat windows and personalities for a moment. Underneath everything, a language model is one thing: a function that receives some text and hands back some text. It runs **once**, produces its answer, and holds on to **nothing**. Ask it something a second time and it has no clue it ever met you.

# %%
def stateless_reply(prompt:str)->str:
    return f"Some LLM response mimicking model's output-- {prompt}"

# %%
stateless_reply("Who is the PM of UK?")
# Out:
# "Some LLM response mimicking model's output-- Who is the PM of UK?"

# %%
stateless_reply("Who was before him?")
# Out:
# "Some LLM response mimicking model's output-- Who was before him?"

# %%
def stateless_chatgpt_demo(prompt:str)->str:
    from dotenv import load_dotenv
    from openai import OpenAI

    load_dotenv()
    client = OpenAI()
    response = client.responses.create(
        model="gpt-4o-mini",
        input=prompt
    )
    return response.output_text

# %%
stateless_chatgpt_demo("Who was the prime minister of UK before 2020?")
# Out:
# 'Before 2020, the Prime Minister of the United Kingdom was Theresa May. She served from July 13, 2016, until July 24, 2019, when Boris Johnson succeeded her.'

# %%
stateless_chatgpt_demo("Who was before him?")
# Out:
# 'Could you please clarify whom you are referring to? With a bit more context, I’d be happy to help!'
